# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df1 = pd.read_csv('../data/DataFrame_minmax/minmax_0905.csv',index_col=0)
df2 = pd.read_csv('../data/DataFrame_minmax/minmax_0910.csv',index_col=0)
df3 = pd.read_csv('../data/DataFrame_minmax/minmax_0915.csv',index_col=0)
df4 = pd.read_csv('../data/DataFrame_minmax/minmax_0920.csv',index_col=0)
df5 = pd.read_csv('../data/DataFrame_minmax/minmax_0925.csv',index_col=0)
df6 = pd.read_csv('../data/DataFrame_minmax/minmax_0930.csv',index_col=0)
df7 = pd.read_csv('../data/DataFrame_minmax/minmax_1000.csv',index_col=0)

# %%
df1.set_index('date', inplace=True)
df2.set_index('date', inplace=True)
df3.set_index('date', inplace=True)
df4.set_index('date', inplace=True)
df5.set_index('date', inplace=True)
df6.set_index('date', inplace=True)
df7.set_index('date', inplace=True)

# %%
df_list = [df1,df2,df3,df4,df5,df6,df7]

# %%
df1
# Out:
#             y_minmax  KODEX_return    PER   PBR  Dividend_Yield  \
# date
# 2021-01-06     151.0         433.0  30.45  1.20            1.43
# 2021-01-07     273.0         514.0  31.11  1.22            1.40
# 2021-01-08     118.0         429.0  32.35  1.27            1.35
# 2021-01-11     156.0        -212.0  32.31  1.27            1.35
# 2021-01-12     282.0          42.0  32.08  1.26            1.36
# ...              ...           ...    ...   ...             ...
# 2023-10-18     125.0        -425.0  18.48  0.89            2.00
# 2023-10-19      70.0        -255.0  18.12  0.88            2.04
# 2023-10-20     105.0         -35.0  17.82  0.86            2.08
# 2023-10-23     100.0         150.0  17.68  0.86            2.09
# 2023-10-24      70.0          90.0  17.88  0.87            2.07
#
#             Kosdaq150_return  S&P500_return  WTI_change  WTI_Volume  T10Y2Y  \
# date
# 2021-01-06              88.0          35.94        0.81      509.37    0.90
# ...

# %%
# 상관계수 행렬 계산
correlation_matrix = df1.corr()

# 히트맵으로 시각화
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title("Correlation Matrix Heatmap")
plt.show()

# %%
# 상관계수 행렬 계산
correlation_matrix = df2.corr()

# 히트맵으로 시각화
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title("Correlation Matrix Heatmap")
plt.show()

# %%
# 상관계수 행렬 계산
correlation_matrix = df3.corr()

# 히트맵으로 시각화
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title("Correlation Matrix Heatmap")
plt.show()

# %%
# 상관계수 행렬 계산
correlation_matrix = df4.corr()

# 히트맵으로 시각화
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title("Correlation Matrix Heatmap")
plt.show()

# %%
# 상관계수 행렬 계산
correlation_matrix = df5.corr()

# 히트맵으로 시각화
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title("Correlation Matrix Heatmap")
plt.show()

# %%
# 상관계수 행렬 계산
correlation_matrix = df6.corr()

# 히트맵으로 시각화
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title("Correlation Matrix Heatmap")
plt.show()

# %%
# 상관계수 행렬 계산
correlation_matrix = df7.corr()

# 히트맵으로 시각화
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title("Correlation Matrix Heatmap")
plt.show()

# %%
# 최근 3개월
for i in df_list :
    i = i[i.index >= '2023-08-01']
    # 상관계수 행렬 계산
    correlation_matrix = i.corr()
    plt.figure(figsize=(10, 8))
    sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
    plt.title("Correlation Matrix Heatmap")
    plt.show()
