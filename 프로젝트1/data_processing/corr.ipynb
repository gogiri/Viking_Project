# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df1 = pd.read_csv('../data/DataFrame/0900_0905.csv',index_col=0)
df2 = pd.read_csv('../data/DataFrame/0900_0910.csv',index_col=0)
df3 = pd.read_csv('../data/DataFrame/0900_0915.csv',index_col=0)
df4 = pd.read_csv('../data/DataFrame/0900_0920.csv',index_col=0)
df5 = pd.read_csv('../data/DataFrame/0900_0925.csv',index_col=0)
df6 = pd.read_csv('../data/DataFrame/0900_0930.csv',index_col=0)
df7 = pd.read_csv('../data/DataFrame/0900_1000.csv',index_col=0)

# %%
df1.set_index('date', inplace=True)
df2.set_index('date', inplace=True)
df3.set_index('date', inplace=True)
df4.set_index('date', inplace=True)
df5.set_index('date', inplace=True)
df6.set_index('date', inplace=True)
df7.set_index('date', inplace=True)

# %%
df1
# Out:
#             y_change  KODEX_return    PER   PBR  Dividend_Yield  \
# date
# 2021-01-05       0.0         113.0  30.68  1.20            1.42
# 2021-01-06       0.0         433.0  30.45  1.20            1.43
# 2021-01-07       0.0         514.0  31.11  1.22            1.40
# 2021-01-08       0.0         429.0  32.35  1.27            1.35
# 2021-01-11       0.0        -212.0  32.31  1.27            1.35
# ...              ...           ...    ...   ...             ...
# 2023-10-18       0.0        -425.0  18.48  0.89            2.00
# 2023-10-19       0.0        -255.0  18.12  0.88            2.04
# 2023-10-20       0.0         -35.0  17.82  0.86            2.08
# 2023-10-23       0.0         150.0  17.68  0.86            2.09
# 2023-10-24       0.0          90.0  17.88  0.87            2.07
#
#             Kosdaq150_return  S&P500_return  WTI_change  WTI_Volume  T10Y2Y  \
# date
# 2021-01-05               0.0          28.84        2.55      643.19    0.83
# ...

# %%
df_list = [df1,df2,df3,df4,df5,df6,df7]

# %%
# 상관계수 행렬 계산
correlation_matrix = df1.corr()

# 히트맵으로 시각화
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title("Correlation Matrix Heatmap")
plt.show()

# %%
# 상관계수 행렬 계산
correlation_matrix = df2.corr()

# 히트맵으로 시각화
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title("Correlation Matrix Heatmap")
plt.show()

# %%
# 상관계수 행렬 계산
correlation_matrix = df3.corr()

# 히트맵으로 시각화
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title("Correlation Matrix Heatmap")
plt.show()

# %%
# 상관계수 행렬 계산
correlation_matrix = df4.corr()

# 히트맵으로 시각화
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title("Correlation Matrix Heatmap")
plt.show()

# %%
# 상관계수 행렬 계산
correlation_matrix = df5.corr()

# 히트맵으로 시각화
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title("Correlation Matrix Heatmap")
plt.show()

# %%
# 상관계수 행렬 계산
correlation_matrix = df6.corr()

# 히트맵으로 시각화
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title("Correlation Matrix Heatmap")
plt.show()

# %%
# 상관계수 행렬 계산
correlation_matrix = df7.corr()

# 히트맵으로 시각화
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title("Correlation Matrix Heatmap")
plt.show()
